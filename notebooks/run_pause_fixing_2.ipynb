# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import contextily as cx
from datetime import datetime, date, timedelta
import seaborn as sns
import shapely

# %%
gdf_track_info = gpd.read_parquet("../data/cleaned/track_info.parquet")
gdf_track_info
# Out:
#                                              track_file  \
# 0     /Users/ryansponzilli/Developer/Python Projects...
# 1     /Users/ryansponzilli/Developer/Python Projects...
# 2     /Users/ryansponzilli/Developer/Python Projects...
# 3     /Users/ryansponzilli/Developer/Python Projects...
# 4     /Users/ryansponzilli/Developer/Python Projects...
# ...                                                 ...
# 1028  /Users/ryansponzilli/Developer/Python Projects...
# 1029  /Users/ryansponzilli/Developer/Python Projects...
# 1030  /Users/ryansponzilli/Developer/Python Projects...
# 1031  /Users/ryansponzilli/Developer/Python Projects...
# 1032  /Users/ryansponzilli/Developer/Python Projects...
#
#            track_file_datetime track_file_date            start_datetime  \
# 0    2019-06-10 07:46:00-05:00      2019-06-10 2019-06-10 11:57:42+00:00
# 1    2019-06-11 07:32:00-05:00      2019-06-11 2019-06-11 11:59:03+00:00
# 2    2019-06-12 07:35:00-05:00      2019-06-12 2019-06-12 11:53:30+00:00
# 3    2019-06-17 07:22:00-05:00      2019-06-17 2019-06-17 11:52:32+00:00
# 4    2019-06-18 07:19:00-05:00      2019-06-18 2019-06-18 11:53:58+00:00
# ...                        ...             ...                       ...
# 1028 2023-05-04 15:10:00-05:00      2023-05-04 2023-05-04 19:54:31+00:00
# 1029 2023-05-04 15:42:00-05:00      2023-05-04 2023-05-04 20:24:15+00:00
# 1030 2023-05-05 15:11:00-05:00      2023-05-05 2023-05-05 19:44:31+00:00
# 1031 2023-05-06 11:15:00-05:00      2023-05-06 2023-05-06 15:58:42+00:00
# 1032 2023-05-08 16:02:00-05:00      2023-05-08 2023-05-08 20:20:18+00:00
#
#                   end_datetime      year           season  total_duration  \
# 0    2019-06-10 12:46:10+00:00  Freshman  Summer Training 0 days 00:48:28
# 1    2019-06-11 12:32:23+00:00  Freshman  Summer Training 0 days 00:33:20
# 2    2019-06-12 12:35:13+00:00  Freshman  Summer Training 0 days 00:41:43
# 3    2019-06-17 12:22:32+00:00  Freshman  Summer Training 0 days 00:30:00
# 4    2019-06-18 12:19:21+00:00  Freshman  Summer Training 0 days 00:25:23
# ...                        ...       ...              ...             ...
# 1028 2023-05-04 20:10:21+00:00    Senior     Track Season 0 days 00:15:50
# 1029 2023-05-04 20:42:07+00:00    Senior     Track Season 0 days 00:17:52
# 1030 2023-05-05 20:11:23+00:00    Senior     Track Season 0 days 00:26:52
# 1031 2023-05-06 16:15:16+00:00    Senior     Track Season 0 days 00:16:34
# 1032 2023-05-08 21:02:16+00:00    Senior     Track Season 0 days 00:41:58
#
#       total_distance (mi)  average_pace (min/mi)  total_elevation_change (m)  \
# 0                3.063156               8.542777                   77.126862
# 1                3.172008               8.767494                  122.178753
# 2                3.052702               8.581829                  132.038013
# 3                2.983042               9.088904                   86.000490
# 4                2.355063               9.380388                   95.971917
# ...                   ...                    ...                         ...
# 1028             2.032107               7.547855                   23.622665
# 1029             0.999846               5.064146                    8.642043
# 1030             3.509378               6.976707                   43.772437
# 1031             1.985944               7.678578                   38.987511
# 1032             2.178453               7.337451                   31.674574
#
#       in_stc                 start_point                   end_point  \
# 0       True  POINT (-88.32154 41.91101)   POINT (-88.32166 41.9109)
# 1       True    POINT (-88.34764 41.928)  POINT (-88.34792 41.92783)
# 2       True  POINT (-88.32152 41.91252)    POINT (-88.32172 41.911)
# 3       True    POINT (-88.32145 41.911)  POINT (-88.32154 41.91096)
# 4       True  POINT (-88.35416 41.92575)  POINT (-88.34797 41.92783)
# ...      ...                         ...                         ...
# 1028    True  POINT (-88.27989 41.92867)  POINT (-88.27976 41.92838)
# 1029    True  POINT (-88.27658 41.92845)  POINT (-88.27658 41.92851)
# 1030    True  POINT (-88.27988 41.92846)   POINT (-88.27952 41.9282)
# 1031    True  POINT (-88.32198 41.95005)  POINT (-88.32167 41.95012)
# 1032    True  POINT (-88.27981 41.92424)  POINT (-88.27743 41.92801)
#
#                                              track_line
# 0     MULTILINESTRING ((-88.32154 41.91101, -88.3215...
# 1     MULTILINESTRING ((-88.34764 41.928, -88.34764 ...
# 2     MULTILINESTRING ((-88.32152 41.91252, -88.3215...
# 3     MULTILINESTRING ((-88.32145 41.911, -88.32143 ...
# 4     MULTILINESTRING ((-88.35416 41.92575, -88.3541...
# ...                                                 ...
# 1028  MULTILINESTRING ((-88.27989 41.92867, -88.2798...
# 1029  MULTILINESTRING ((-88.27658 41.92845, -88.2765...
# 1030  MULTILINESTRING ((-88.27988 41.92846, -88.2798...
# 1031  MULTILINESTRING ((-88.32198 41.95005, -88.3219...
# 1032  MULTILINESTRING ((-88.27981 41.92424, -88.2798...
#
# [1033 rows x 15 columns]

# %%
pause_line = gdf_track_info.loc[gdf_track_info['start_datetime'] > pd.to_datetime(datetime(2023, 2, 7), utc=True), 'track_file'].iloc[0]
pause_line
# Out:
# '/Users/ryansponzilli/Developer/Python Projects/health-data/data/raw/apple_health/apple_health_export/workout-routes/route_2023-02-07_3.48pm.gpx'

# %%
# parse file
gdf = gpd.read_file(pause_line, layer="track_points")
gdf = gdf[["time", "ele", "geometry"]]
gdf["time"] = pd.to_datetime(gdf["time"])
gdf = gdf.rename(columns={"time": "datetime", "ele": "elevation"})

# create helper columns
gdf['dt'] = gdf["datetime"].diff()
gdf_utm = gdf.to_crs(gdf.estimate_utm_crs())
gdf["dx"] = gdf_utm["geometry"].distance(gdf_utm["geometry"].shift())

# split into segments at pause indices
pause_idx = list(gdf.loc[gdf['dt'] > timedelta(seconds=1)].index)
gdf['pause_segment'] = None
segment_idx = ([0] + pause_idx + [len(gdf)])
for i in range(len(segment_idx) - 1):
    gdf.loc[segment_idx[i]:segment_idx[i+1], 'pause_segment'] = i

# remove segments less than 5 seconds
gdf = gdf.groupby("pause_segment", group_keys=False).filter(lambda x: len(x) >= 5)

# calculate pace for each pause segment separately
def calculate_rolling_pace(gdf):
    # use a 10 second rolling window for calculating pace
    gdf["pace (min/mi)"] = (gdf["dt"].cumsum().dt.total_seconds() / 60).diff(10) / (gdf["dx"].cumsum() / 1609).diff(10)
    # backfill nans that resulted from the rolling window
    gdf["pace (min/mi)"] = gdf["pace (min/mi)"].bfill()
    return gdf
gdf = gdf.groupby('pause_segment').apply(calculate_rolling_pace).reset_index().drop(columns=["level_1"], errors='ignore')

gdf
# Out:
#       pause_segment                  datetime   elevation  \
# 0                 0 2023-02-07 21:13:31+00:00  236.657103
# 1                 0 2023-02-07 21:13:32+00:00  236.608273
# 2                 0 2023-02-07 21:13:33+00:00  236.587713
# 3                 0 2023-02-07 21:13:34+00:00  236.484079
# 4                 0 2023-02-07 21:13:35+00:00  236.343193
# ...             ...                       ...         ...
# 1261              1 2023-02-07 21:47:58+00:00  236.227632
# 1262              1 2023-02-07 21:47:59+00:00  236.210292
# 1263              1 2023-02-07 21:48:00+00:00  236.194119
# 1264              1 2023-02-07 21:48:01+00:00  236.178369
# 1265              1 2023-02-07 21:48:02+00:00  236.162441
#
#                         geometry              dt        dx  pace (min/mi)
# 0      POINT (-88.27581 41.9252)             NaT       NaN      24.171964
# 1     POINT (-88.27581 41.92519) 0 days 00:00:01  1.199533      24.171964
# 2      POINT (-88.2758 41.92518) 0 days 00:00:01  1.385900      24.171964
# 3     POINT (-88.27578 41.92517) 0 days 00:00:01  1.437056      24.171964
# 4     POINT (-88.27577 41.92516) 0 days 00:00:01  1.437057      24.171964
# ...                          ...             ...       ...            ...
# 1261  POINT (-88.27554 41.92515) 0 days 00:00:01  2.226416      10.166711
# 1262  POINT (-88.27556 41.92514) 0 days 00:00:01  2.098783      10.517239
# 1263  POINT (-88.27559 41.92513) 0 days 00:00:01  1.942224      10.926442
# 1264  POINT (-88.27561 41.92513) 0 days 00:00:01  1.787341      11.447533
# 1265  POINT (-88.27562 41.92512) 0 days 00:00:01  1.515136      12.141602
#
# [1266 rows x 7 columns]

# %%
# calculate number of pauses, where a pause is defined as dt > 1 second
num_pauses = len(gdf.loc[gdf['dt'] > timedelta(seconds=1)])
print(num_pauses)

# calculate the total duration, defined as the time between starting and ending the activity
total_duration = gdf['dt'].sum()
print(total_duration)

# calculate the active duration, defined as the total time minus any pauses
active_duration = gdf.loc[gdf['dt'] == timedelta(seconds=1), 'dt'].sum()
print(active_duration)

# calculate total distance, excluding pauses
total_distance_miles = gdf.loc[(gdf['dt'] == timedelta(seconds=1)), 'dx'].sum() / 1609
print(total_distance_miles)

# calculate average pace, exclude any pace over 10 min/mi since those are not representative of actual running
average_pace = gdf.loc[gdf["pace (min/mi)"] < 10, "pace (min/mi)"].mean()
print(average_pace)

# calculate total ascent, excluding pauses
total_ascent = gdf.loc[(gdf['dt'] == timedelta(seconds=1)), 'elevation'].diff().loc[gdf['elevation'].diff() > 0].sum()
print(total_ascent)

# calculate total descent, excluding pauses
total_descent = gdf.loc[(gdf['dt'] == timedelta(seconds=1)), 'elevation'].diff().loc[gdf['elevation'].diff() < 0].sum()
print(total_descent)

# split each pause segment into a LineString within a MultiLineString
fixed_track_line = shapely.MultiLineString([shapely.LineString(group['geometry']) for _, group in gdf.groupby('pause_segment')])
display(fixed_track_line)
# Out:
# 1
# 0 days 00:34:31
# 0 days 00:21:04
# 2.4336877055889525
# 7.4397892960859755
# 18.098955000000046
# -18.544787000000042
# <MULTILINESTRING ((-88.276 41.925, -88.276 41.925, -88.276 41.925, -88.276 4...>
